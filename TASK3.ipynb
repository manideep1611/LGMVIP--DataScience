# %% [markdown]
# TASK 3 - Exploratory Data Analysis on Dataset - Terrorism

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Load the data 
from google.colab import files 
#Use to load data on Google Colab 
uploaded = files.upload()
#Use to load data on Google Colab
df=pd.read_csv('globalterrorismdb_0718dist.csv',encoding='latin1',low_memory=False)
df.head(20)
# Out:
#      <input type="file" id="files-7f4056e1-e58b-441f-b2c8-04f18d87570d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f4056e1-e58b-441f-b2c8-04f18d87570d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving globalterrorismdb_0718dist.csv to globalterrorismdb_0718dist.csv
#          eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0   197000000001   1970       7     2        NaN         0        NaN
# 1   197000000002   1970       0     0        NaN         0        NaN
# 2   197001000001   1970       1     0        NaN         0        NaN
# 3   197001000002   1970       1     0        NaN         0        NaN
# 4   197001000003   1970       1     0        NaN         0        NaN
# 5   197001010002   1970       1     1        NaN         0        NaN
# 6   197001020001   1970       1     2        NaN         0        NaN
# 7   197001020002   1970       1     2        NaN         0        NaN
# 8   197001020003   1970       1     2        NaN         0        NaN
# 9   197001030001   1970       1     3        NaN         0        NaN
# 10  197001050001   1970       1     1        NaN         0        NaN
# 11  197001060001   1970       1     6        NaN         0        NaN
# 12  197001080001   1970       1     8        NaN         0        NaN
# 13  197001090001   1970       1     9        NaN         0        NaN
# 14  197001090002   1970       1     9        NaN         0        NaN
# 15  197001100001   1970       1    10        NaN         0        NaN
# 16  197001110001   1970       1    11        NaN         0        NaN
# 17  197001120001   1970       1    12        NaN         0        NaN
# 18  197001120002   1970       1    12        NaN         0        NaN
# 19  197001130001   1970       1    13        NaN         0        NaN
#
#     country         country_txt  region  ...  \
# 0        58  Dominican Republic       2  ...
# 1       130              Mexico       1  ...
# 2       160         Philippines       5  ...
# 3        78              Greece       8  ...
# 4       101               Japan       4  ...
# 5       217       United States       1  ...
# 6       218             Uruguay       3  ...
# 7       217       United States       1  ...
# 8       217       United States       1  ...
# 9       217       United States       1  ...
# 10      217       United States       1  ...
# 11      217       United States       1  ...
# 12       98               Italy       8  ...
# 13      217       United States       1  ...
# 14      217       United States       1  ...
# 15      499  East Germany (GDR)       9  ...
# 16       65            Ethiopia      11  ...
# 17      217       United States       1  ...
# 18      217       United States       1  ...
# 19      217       United States       1  ...
#
#                                              addnotes  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   The Cairo Chief of Police, William Petersen, r...
# 6                                                 NaN
# 7   Damages were estimated to be between $20,000-$...
# 8   The New Years Gang issue a communiqué to a loc...
# 9   Karl Armstrong's girlfriend, Lynn Schultz, dro...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  The fire began at 8:30 PM. The Armed Commandos...
# 15                                                NaN
# 16                                                NaN
# 17  One half hour after the bomb explosion, an ano...
# 18                                                NaN
# 19  The store was a White owned business operating...
#
#                                                scite1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   "Police Chief Quits," Washington Post, January...
# 6                                                 NaN
# 7   Committee on Government Operations United Stat...
# 8   Tom Bates, "Rads: The 1970 Bombing of the Army...
# 9   Committee on Government Operations United Stat...
# 10                                                NaN
# 11  Committee on Government Operations United Stat...
# 12                                                NaN
# 13  Committee on Government Operations United Stat...
# 14  Committee on the Judiciary  United States Sena...
# 15                                                NaN
# 16                                                NaN
# 17  "Blast Damages Flatbush School," New York Time...
# 18  Committee on the Judiciary  United States Sena...
# 19  Committee on Government Operations United Stat...
#
#                                                scite2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   "Cairo Police Chief Quits; Decries Local 'Mili...
# 6                                                 NaN
# 7   Christopher Hewitt, "Political Violence and Te...
# 8   David Newman, Sandra Sutherland, and Jon Stewa...
# 9   Tom Bates, "Rads: The 1970 Bombing of the Army...
# 10                                                NaN
# 11  Christopher Hewitt, "Political Violence and Te...
# 12                                                NaN
# 13  Christopher Hewitt, "Political Violence and Te...
# 14  "No Evidence Of Arson Found In Barkers Fire," ...
# 15                                                NaN
# 16                                                NaN
# 17  Linda Greenhouse, "Madison School Puzzled By B...
# 18  "Toward People's War for Independence and Soci...
# 19                                                NaN
#
#                                                scite3        dbsource  \
# 0                                                 NaN            PGIS
# 1                                                 NaN            PGIS
# 2                                                 NaN            PGIS
# 3                                                 NaN            PGIS
# 4                                                 NaN            PGIS
# 5   Christopher Hewitt, "Political Violence and Te...  Hewitt Project
# 6                                                 NaN            PGIS
# 7                                                 NaN  Hewitt Project
# 8   The Wisconsin Cartographers' Guild, "Wisconsin...  Hewitt Project
# 9   David Newman, Sandra Sutherland, and Jon Stewa...  Hewitt Project
# 10                                                NaN            PGIS
# 11                                                NaN  Hewitt Project
# 12                                                NaN    Hijacking DB
# 13                                                NaN  Hewitt Project
# 14  "Toward People's War for Independence and Soci...  Hewitt Project
# 15                                                NaN            PGIS
# 16                                                NaN            PGIS
# 17  Committee on Government Operations United Stat...  Hewitt Project
# 18                                                NaN  Hewitt Project
# 19                                                NaN  Hewitt Project
#
#     INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0         0         0        0       0      NaN
# 1         0         1        1       1      NaN
# 2        -9        -9        1       1      NaN
# 3        -9        -9        1       1      NaN
# 4        -9        -9        1       1      NaN
# 5        -9        -9        0      -9      NaN
# 6         0         0        0       0      NaN
# 7        -9        -9        0      -9      NaN
# 8         0         0        0       0      NaN
# 9         0         0        0       0      NaN
# 10        0         0        0       0      NaN
# 11       -9        -9        0      -9      NaN
# 12       -9        -9        1       1      NaN
# 13       -9        -9        0      -9      NaN
# 14        0         0        0       0      NaN
# 15        0         1        1       1      NaN
# 16        0         1        1       1      NaN
# 17       -9        -9        0      -9      NaN
# 18       -9        -9        0      -9      NaN
# 19       -9        -9        0      -9      NaN
#
# [20 rows x 135 columns]
# Warning: Total number of columns (135) exceeds max_columns (20) limiting to first (20) columns.

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB
# (181691, 135)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       5.000000      11.510046
# 50%         0.000000      98.000000       6.000000      31.467463
# 75%         0.000000     160.000000      10.000000      34.685087
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity  ...     ransomamt   ransomamtus  \
# count  1.771340e+05  181685.000000  ...  1.350000e+03  5.630000e+02
# mean  -4.586957e+02       1.451452  ...  3.172530e+06  5.784865e+05
# std    2.047790e+05       0.995430  ...  3.021157e+07  7.077924e+06
# min   -8.618590e+07       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%    4.545640e+00       1.000000  ...  0.000000e+00  0.000000e+00
# 50%    4.324651e+01       1.000000  ...  1.500000e+04  0.000000e+00
# 75%    6.871033e+01       1.000000  ...  4.000000e+05  0.000000e+00
# max    1.793667e+02       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  7.740000e+02    552.000000    10991.000000  10400.000000
# mean   7.179437e+05    240.378623        4.629242    -29.018269
# std    1.014392e+07   2940.967293        2.035360     65.720119
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2769.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean       -4.543731      -4.464398       0.090010      -3.945952
# std         4.543547       4.637152       0.568457       4.691325
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]
# Warning: Total number of columns (77) exceeds max_columns (20) limiting to first (20) columns.

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','city':'City','iday':'Day','country_txt':'Country','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type','weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)
df['Casualities'] = df.Killed + df.Wounded
df=df[['Year','Month','Day','Country','Region','City','latitude','longitude','AttackType','Killed','Wounded','Casualities','Target','Group','Target_type','Weapon_type']]
df.head(11)
# Out:
#     Year  Month  Day             Country                       Region  \
# 0   1970      7    2  Dominican Republic  Central America & Caribbean
# 1   1970      0    0              Mexico                North America
# 2   1970      1    0         Philippines               Southeast Asia
# 3   1970      1    0              Greece               Western Europe
# 4   1970      1    0               Japan                    East Asia
# 5   1970      1    1       United States                North America
# 6   1970      1    2             Uruguay                South America
# 7   1970      1    2       United States                North America
# 8   1970      1    2       United States                North America
# 9   1970      1    3       United States                North America
# 10  1970      1    1       United States                North America
#
#              City   latitude   longitude                      AttackType  \
# 0   Santo Domingo  18.456792  -69.951164                   Assassination
# 1     Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2         Unknown  15.478598  120.599741                   Assassination
# 3          Athens  37.997490   23.762728               Bombing/Explosion
# 4         Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
# 5           Cairo  37.005105  -89.176269                   Armed Assault
# 6      Montevideo -34.891151  -56.187214                   Assassination
# 7         Oakland  37.791927 -122.225906               Bombing/Explosion
# 8         Madison  43.076592  -89.412488  Facility/Infrastructure Attack
# 9         Madison  43.072950  -89.386694  Facility/Infrastructure Attack
# 10        Baraboo  43.468500  -89.744299               Bombing/Explosion
#
#     Killed  Wounded  Casualities  \
# 0      1.0      0.0          1.0
# 1      0.0      0.0          0.0
# 2      1.0      0.0          1.0
# 3      NaN      NaN          NaN
# 4      NaN      NaN          NaN
# 5      0.0      0.0          0.0
# 6      0.0      0.0          0.0
# 7      0.0      0.0          0.0
# 8      0.0      0.0          0.0
# 9      0.0      0.0          0.0
# 10     0.0      0.0          0.0
#
#                                                Target  \
# 0                                        Julio Guzman
# 1                             Nadine Chaval, daughter
# 2                                            Employee
# 3                                        U.S. Embassy
# 4                                      U.S. Consulate
# 5                           Cairo Police Headquarters
# 6   Juan Maria de Lucah/Chief of Directorate of in...
# 7                                     Edes Substation
# 8   R.O.T.C. offices at University of Wisconsin, M...
# 9   Selective Service Headquarters in Madison Wisc...
# 10                            Badger Army ammo depot.
#
#                                  Group                  Target_type  \
# 0                               MANO-D  Private Citizens & Property
# 1   23rd of September Communist League      Government (Diplomatic)
# 2                              Unknown          Journalists & Media
# 3                              Unknown      Government (Diplomatic)
# 4                              Unknown      Government (Diplomatic)
# 5                   Black Nationalists                       Police
# 6                  Tupamaros (Uruguay)                       Police
# 7                              Unknown                    Utilities
# 8                      New Year's Gang                     Military
# 9                      New Year's Gang         Government (General)
# 10     Weather Underground, Weathermen                     Military
#
#    Weapon_type
# 0      Unknown
# 1      Unknown
# 2      Unknown
# 3   Explosives
# 4   Incendiary
# 5     Firearms
# 6     Firearms
# 7   Explosives
# 8   Incendiary
# 9   Incendiary
# 10  Explosives

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 16 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   Region       181691 non-null  object
#  5   City         181257 non-null  object
#  6   latitude     177135 non-null  float64
#  7   longitude    177134 non-null  float64
#  8   AttackType   181691 non-null  object
#  9   Killed       171378 non-null  float64
#  10  Wounded      165380 non-null  float64
#  11  Casualities  164817 non-null  float64
#  12  Target       181055 non-null  object
#  13  Group        181691 non-null  object
#  14  Target_type  181691 non-null  object
#  15  Weapon_type  181691 non-null  object
# dtypes: float64(5), int64(3), object(8)
# memory usage: 22.2+ MB

# %%
#renamed coloumns
df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'City', 'latitude',
#        'longitude', 'AttackType', 'Killed', 'Wounded', 'Casualities', 'Target',
#        'Group', 'Target_type', 'Weapon_type'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 Year          Month            Day       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           longitude         Killed        Wounded    Casualities
# count  1.771340e+05  171378.000000  165380.000000  164817.000000
# mean  -4.586957e+02       2.403272       3.167668       5.296128
# std    2.047790e+05      11.545741      35.949392      42.069023
# min   -8.618590e+07       0.000000       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000       1.000000
# 75%    6.871033e+01       2.000000       2.000000       4.000000
# max    1.793667e+02    1570.000000    8191.000000    9574.000000

# %%
#dropping unwanted coloumns
df.dropna(axis=0, inplace=True)
df.shape
# Out:
# (159946, 16)

# %%
#checking
df.isnull().sum()
# Out:
# Year           0
# Month          0
# Day            0
# Country        0
# Region         0
# City           0
# latitude       0
# longitude      0
# AttackType     0
# Killed         0
# Wounded        0
# Casualities    0
# Target         0
# Group          0
# Target_type    0
# Weapon_type    0
# dtype: int64

# %% [markdown]
# DATA ANALYSIS AND VISUALISATION

# %%
#yearly count
plt.figure(figsize=(12,8))
sns.countplot(x="Year",data=df)
plt.xticks(rotation=90)
plt.title('Yearly Attacks')
plt.show()

# %%
#monthly analysis
df['Month'].value_counts()
# Out:
# 5     14641
# 7     14425
# 8     13947
# 10    13730
# 6     13590
# 4     13327
# 11    13273
# 3     13230
# 1     13001
# 9     12590
# 2     12243
# 12    11942
# 0         7
# Name: Month, dtype: int64

# %%
plt.figure(figsize = (10, 6))
sns.countplot(x='Month', data = df)
plt.xticks(rotation=90)
plt.show()

# %%
#regional analysis
df['Region'].value_counts()
# Out:
# Middle East & North Africa     45817
# South Asia                     42261
# South America                  16240
# Sub-Saharan Africa             13833
# Western Europe                 13816
# Southeast Asia                 11226
# Central America & Caribbean     7089
# Eastern Europe                  4833
# North America                   3283
# East Asia                        744
# Central Asia                     537
# Australasia & Oceania            267
# Name: Region, dtype: int64

# %%
#affected regions
df['Region'].value_counts()
plt.figure(figsize=(12,6))
sns.countplot(x='Region',data=df)
plt.xticks(rotation=70)
plt.show()

# %%
#top 10 affected countries
plt.subplots(figsize=(12,6))
sns.barplot(df['Country'].value_counts()[:10].index,df['Country'].value_counts()[:10].values,palette='Blues_d')
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()

# %%
# %pip install plotly matplotlib seaborn --quiet

# %%
#target types
import plotly.express as px
from collections import Counter
target = list(df['Target_type'])
target_map = dict(Counter(target))
target_df = pd.DataFrame(target_map.items())
target_df.columns = ['Target Type','Count']
px.bar(data_frame=target_df,x = 'Target Type',y = 'Count',color='Target Type',template='plotly_white')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a2d80d37-1fda-4821-be3b-142ff3d603cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2d80d37-1fda-4821-be3b-142ff3d603cf")) {                    Plotly.newPlot(                        "a2d80d37-1fda-4821-be3b-142ff3d603cf",                        [{"alignmentgroup":"True","hovertemplate":"Target Type=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Private Citizens & Property","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Private Citizens & Property","offsetgroup":"Private Citizens & Property","orientation":"v","showlegend":true,"textposition":"auto","x":["Private Citizens & Property"],"xaxis":"x","y":[37463],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Target Type=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Government (Diplomatic)","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Government (Diplomatic)","offsetgroup":"Government (Diplomatic)","orientation":"v","showlegend":true,"textposition":"auto","x":["Government (Diplomatic)"],"xaxis":"x","y":[3271],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Target Type=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Journalists & Media","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Journalists & Media","offsetgroup":"Journalists & Media","orientation":"v","showlegend":true,"textposition":"auto","x":["Journalists & Media"],"xaxis":"x","y":[2597],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Target Type=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Police","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Police","offsetgroup":"Police","orientation":"v","showlegend":true,"textposition":"auto","x":["Police"],"xaxis":"x","y":[22560],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Target Type=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Utilities","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Utilities","offsetgroup":"Utilities","orientation":"v","showlegend":true,"textposition":"auto","x":["Utilities"],"xaxis":"x","y":[4930],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Target Type=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Military","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Military","offsetgroup":"Military","orientation":"v","showlegend":true,"textposition":"auto","x":["Military"],"xaxis":"x","y":[23006],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Target Type=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Government (General)","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Government (General)","offsetgroup":"Government (General)","orientation":"v","showlegend":true,"textposition":"auto","x":["Government (General)"],"xaxis":"x","y":[19494],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Target Type=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Airports & Aircraft","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Airports & Aircraft","offsetgroup":"Airports & Aircraft","orientation":"v","showlegend":true,"textposition":"auto","x":["Airports & Aircraft"],"xaxis":"x","y":[1142],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Target Type=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Business","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Business","offsetgroup":"Business","orientation":"v","showlegend":true,"textposition":"auto","x":["Business"],"xaxis":"x","y":[18323],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Target Type=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Educational Institution","marker":{"color":"#FECB52","pattern":{"shape":""}},"n ...

# %%
#attack types
df.AttackType.value_counts().plot.bar()
plt.xlabel('Attack Types')
plt.ylabel('count')
plt.title('Type')
plt.show()

# %%
#favorite targets
df['Target_type'].value_counts().plot(kind='pie',figsize=[12,10],autopct='%1.1f%%')
plt.title('Favorite Targets')
# Out:
# Text(0.5, 1.0, 'Favorite Targets')
